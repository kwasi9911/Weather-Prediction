# %%
import pandas as pd

weather = pd.read_csv("weather.csv", index_col="DATE")

# %%
weather
# Out:
#                 STATION                                       NAME  ACMH  \
# DATE
# 1970-01-01  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  80.0
# 1970-01-02  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  20.0
# 1970-01-03  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  80.0
# 1970-01-04  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US   0.0
# 1970-01-05  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  50.0
# ...                 ...                                        ...   ...
# 2024-03-24  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US   NaN
# 2024-03-25  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US   NaN
# 2024-03-26  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US   NaN
# 2024-03-27  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US   NaN
# 2024-03-28  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US   NaN
#
#              ACSH  AWND  FMTM    PGTM  PRCP   PSUN  SNOW  ...  WT13  WT14  \
# DATE                                                      ...
# 1970-01-01  100.0   NaN   NaN     NaN  0.00    3.0   0.0  ...   NaN   NaN
# 1970-01-02   30.0   NaN   NaN     NaN  0.00   75.0   0.0  ...   NaN   NaN
# 1970-01-03  100.0   NaN   NaN     NaN  0.04    0.0   0.4  ...   NaN   NaN
# 1970-01-04    0.0   NaN   NaN     NaN  0.00  100.0   0.0  ...   NaN   NaN
# 1970-01-05   60.0   NaN   NaN     NaN  0.00   66.0   0.0  ...   NaN   NaN
# ...           ...   ...   ...     ...   ...    ...   ...  ...   ...   ...
# 2024-03-24    NaN  9.62   NaN     NaN  0.00    NaN   0.0  ...   NaN   NaN
# 2024-03-25    NaN  8.72   NaN     NaN  0.00    NaN   0.0  ...   NaN   NaN
# 2024-03-26    NaN  6.71   NaN     NaN  0.00    NaN   0.0  ...   NaN   NaN
# 2024-03-27    NaN  4.25   NaN  1611.0  0.33    NaN   0.0  ...   NaN   NaN
# 2024-03-28    NaN   NaN   NaN     NaN  0.07    NaN   0.0  ...   NaN   NaN
#
#             WT15  WT16  WT17  WT18  WT19  WT21  WT22  WV03
# DATE
# 1970-01-01   NaN   NaN   NaN   1.0   NaN   NaN   NaN   NaN
# 1970-01-02   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1970-01-03   NaN   1.0   NaN   1.0   NaN   NaN   NaN   NaN
# 1970-01-04   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1970-01-05   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...          ...   ...   ...   ...   ...   ...   ...   ...
# 2024-03-24   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2024-03-25   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2024-03-26   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2024-03-27   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2024-03-28   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [19811 rows x 48 columns]

# %%
null_pct = weather.apply(pd.isnull).sum()/weather.shape[0]

# %%
null_pct
# Out:
# STATION    0.000000
# NAME       0.000000
# ACMH       0.522336
# ACSH       0.522286
# AWND       0.258240
# FMTM       0.487255
# PGTM       0.344455
# PRCP       0.000000
# PSUN       0.736258
# SNOW       0.000000
# SNWD       0.000050
# TAVG       0.673060
# TMAX       0.000000
# TMIN       0.000000
# TOBS       0.999950
# TSUN       0.334360
# WDF1       0.966736
# WDF2       0.477815
# WDF5       0.478371
# WDFG       0.596133
# WDFM       0.623442
# WESD       0.695321
# WSF1       0.966736
# WSF2       0.477815
# WSF5       0.478320
# WSFG       0.595982
# WSFM       0.623088
# WT01       0.575791
# WT02       0.964616
# WT03       0.920600
# WT04       0.982989
# WT05       0.981223
# WT06       0.989450
# WT07       0.995911
# WT08       0.750492
# WT09       0.997072
# WT10       0.999950
# WT11       0.998334
# WT13       0.879612
# WT14       0.957801
# WT15       0.998486
# WT16       0.665337
# WT17       0.995659
# WT18       0.942709
# WT19       0.998536
# WT21       0.998587
# WT22       0.998132
# WV03       0.999950
# dtype: float64

# %%
valid_columns = weather.columns[null_pct < .05]

# %%
valid_columns
# Out:
# Index(['station', 'name', 'prcp', 'snow', 'snwd', 'tmax', 'tmin'], dtype='object')

# %%
weather = weather[valid_columns].copy()

# %%
weather.columns = weather.columns.str.lower()

# %%
weather
# Out:
#                 station                                       name  prcp  \
# DATE
# 1970-01-01  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 1970-01-02  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 1970-01-03  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.04
# 1970-01-04  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 1970-01-05  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# ...                 ...                                        ...   ...
# 2024-03-24  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 2024-03-25  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 2024-03-26  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 2024-03-27  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.33
# 2024-03-28  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.07
#
#             snow  snwd  tmax  tmin
# DATE
# 1970-01-01   0.0   0.0    30    23
# 1970-01-02   0.0   0.0    34    18
# 1970-01-03   0.4   0.0    34    24
# 1970-01-04   0.0   0.0    28    19
# 1970-01-05   0.0   0.0    35    16
# ...          ...   ...   ...   ...
# 2024-03-24   0.0   0.0    49    29
# 2024-03-25   0.0   0.0    55    34
# 2024-03-26   0.0   0.0    60    38
# 2024-03-27   0.0   0.0    50    43
# 2024-03-28   0.0   0.0    51    45
#
# [19811 rows x 7 columns]

# %%
weather = weather.ffill()

# %%
weather.apply(pd.isnull).sum()
# Out:
# station    0
# name       0
# prcp       0
# snow       0
# snwd       0
# tmax       0
# tmin       0
# dtype: int64

# %%
weather.dtypes
# Out:
# station     object
# name        object
# prcp       float64
# snow       float64
# snwd       float64
# tmax         int64
# tmin         int64
# dtype: object

# %%
weather.index
# Out:
# Index(['1970-01-01', '1970-01-02', '1970-01-03', '1970-01-04', '1970-01-05',
#        '1970-01-06', '1970-01-07', '1970-01-08', '1970-01-09', '1970-01-10',
#        ...
#        '2024-03-19', '2024-03-20', '2024-03-21', '2024-03-22', '2024-03-23',
#        '2024-03-24', '2024-03-25', '2024-03-26', '2024-03-27', '2024-03-28'],
#       dtype='object', name='DATE', length=19811)

# %%
weather.index = pd.to_datetime(weather.index)

# %%
weather.index
# Out:
# DatetimeIndex(['1970-01-01', '1970-01-02', '1970-01-03', '1970-01-04',
#                '1970-01-05', '1970-01-06', '1970-01-07', '1970-01-08',
#                '1970-01-09', '1970-01-10',
#                ...
#                '2024-03-19', '2024-03-20', '2024-03-21', '2024-03-22',
#                '2024-03-23', '2024-03-24', '2024-03-25', '2024-03-26',
#                '2024-03-27', '2024-03-28'],
#               dtype='datetime64[ns]', name='DATE', length=19811, freq=None)

# %%
weather.index.year.value_counts().sort_index()
# Out:
# DATE
# 1970    365
# 1971    365
# 1972    366
# 1973    365
# 1974    365
# 1975    365
# 1976    366
# 1977    365
# 1978    365
# 1979    365
# 1980    366
# 1981    365
# 1982    365
# 1983    365
# 1984    366
# 1985    365
# 1986    365
# 1987    365
# 1988    366
# 1989    365
# 1990    365
# 1991    365
# 1992    366
# 1993    365
# 1994    365
# 1995    365
# 1996    366
# 1997    365
# 1998    365
# 1999    365
# 2000    366
# 2001    365
# 2002    365
# 2003    365
# 2004    366
# 2005    365
# 2006    365
# 2007    365
# 2008    366
# 2009    365
# 2010    365
# 2011    365
# 2012    366
# 2013    365
# 2014    365
# 2015    365
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2020    366
# 2021    365
# 2022    365
# 2023    365
# 2024     88
# Name: count, dtype: int64

# %%
weather["snwd"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
weather
# Out:
#                 station                                       name  prcp  \
# DATE
# 1970-01-01  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 1970-01-02  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 1970-01-03  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.04
# 1970-01-04  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 1970-01-05  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# ...                 ...                                        ...   ...
# 2024-03-24  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 2024-03-25  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 2024-03-26  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 2024-03-27  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.33
# 2024-03-28  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.07
#
#             snow  snwd  tmax  tmin
# DATE
# 1970-01-01   0.0   0.0    30    23
# 1970-01-02   0.0   0.0    34    18
# 1970-01-03   0.4   0.0    34    24
# 1970-01-04   0.0   0.0    28    19
# 1970-01-05   0.0   0.0    35    16
# ...          ...   ...   ...   ...
# 2024-03-24   0.0   0.0    49    29
# 2024-03-25   0.0   0.0    55    34
# 2024-03-26   0.0   0.0    60    38
# 2024-03-27   0.0   0.0    50    43
# 2024-03-28   0.0   0.0    51    45
#
# [19811 rows x 7 columns]

# %%
weather["target"] = weather.shift(-1)["tmax"]

# %%
weather
# Out:
#                 station                                       name  prcp  \
# DATE
# 1970-01-01  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 1970-01-02  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 1970-01-03  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.04
# 1970-01-04  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 1970-01-05  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# ...                 ...                                        ...   ...
# 2024-03-24  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 2024-03-25  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 2024-03-26  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 2024-03-27  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.33
# 2024-03-28  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.07
#
#             snow  snwd  tmax  tmin  target
# DATE
# 1970-01-01   0.0   0.0    30    23    34.0
# 1970-01-02   0.0   0.0    34    18    34.0
# 1970-01-03   0.4   0.0    34    24    28.0
# 1970-01-04   0.0   0.0    28    19    35.0
# 1970-01-05   0.0   0.0    35    16    36.0
# ...          ...   ...   ...   ...     ...
# 2024-03-24   0.0   0.0    49    29    55.0
# 2024-03-25   0.0   0.0    55    34    60.0
# 2024-03-26   0.0   0.0    60    38    50.0
# 2024-03-27   0.0   0.0    50    43    51.0
# 2024-03-28   0.0   0.0    51    45     NaN
#
# [19811 rows x 8 columns]

# %%
weather = weather.ffill()

# %%
weather
# Out:
#                 station                                       name  prcp  \
# DATE
# 1970-01-01  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 1970-01-02  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 1970-01-03  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.04
# 1970-01-04  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 1970-01-05  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# ...                 ...                                        ...   ...
# 2024-03-24  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 2024-03-25  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 2024-03-26  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 2024-03-27  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.33
# 2024-03-28  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.07
#
#             snow  snwd  tmax  tmin  target
# DATE
# 1970-01-01   0.0   0.0    30    23    34.0
# 1970-01-02   0.0   0.0    34    18    34.0
# 1970-01-03   0.4   0.0    34    24    28.0
# 1970-01-04   0.0   0.0    28    19    35.0
# 1970-01-05   0.0   0.0    35    16    36.0
# ...          ...   ...   ...   ...     ...
# 2024-03-24   0.0   0.0    49    29    55.0
# 2024-03-25   0.0   0.0    55    34    60.0
# 2024-03-26   0.0   0.0    60    38    50.0
# 2024-03-27   0.0   0.0    50    43    51.0
# 2024-03-28   0.0   0.0    51    45    51.0
#
# [19811 rows x 8 columns]

# %%
from sklearn.linear_model import Ridge

rr = Ridge(alpha=.1)

# %%
predictors = weather.columns[~weather.columns.isin(["target", "name", "station"])]

# %%
predictors
# Out:
# Index(['prcp', 'snow', 'snwd', 'tmax', 'tmin'], dtype='object')

# %%
def backtest(weather, model, predictors, start=3650, step=90):
    all_predictions = []

    for i in range(start, weather.shape[0], step):
        train = weather.iloc[:i,:]
        test = weather.iloc[i:(i+step),:]
    
        model.fit(train[predictors], train["target"])
        preds = model.predict(test[predictors])
    
        preds = pd.Series(preds, index=test.index)
        combined = pd.concat([test["target"], preds], axis=1)
    
        combined.columns = ["actual", "prediction"]
        combined["diff"] = (combined["prediction"] - combined["actual"]).abs()
    
        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
predictions = backtest(weather, rr, predictors)

# %%
predictions
# Out:
#             actual  prediction       diff
# DATE
# 1979-12-30    46.0   51.053161   5.053161
# 1979-12-31    43.0   47.200233   4.200233
# 1980-01-01    37.0   44.681413   7.681413
# 1980-01-02    37.0   42.239914   5.239914
# 1980-01-03    28.0   41.498160  13.498160
# ...            ...         ...        ...
# 2024-03-24    55.0   49.081037   5.918963
# 2024-03-25    60.0   54.511477   5.488523
# 2024-03-26    50.0   58.982460   8.982460
# 2024-03-27    51.0   53.539873   2.539873
# 2024-03-28    51.0   55.410678   4.410678
#
# [16161 rows x 3 columns]

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(predictions["actual"], predictions["prediction"])
# Out:
# 5.659678495686212

# %%
def pct_diff(old, new):
    return (new - old) / old

def compute_rolling(weather, horizon, col):
    label = f"rolling_{horizon}_{col}"

    weather[label] = weather[col].rolling(horizon).mean()
    weather[f"{label}_pct"] = pct_diff(weather[label], weather[col])
    return weather 
    
rolling_horizons = [3, 14]

for horizon in rolling_horizons:
    for col in ["tmax", "tmin", "prcp"]:
        weather = compute_rolling(weather, horizon, col)

# %%
weather
# Out:
#                 station                                       name  prcp  \
# DATE
# 1970-01-01  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 1970-01-02  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 1970-01-03  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.04
# 1970-01-04  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 1970-01-05  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# ...                 ...                                        ...   ...
# 2024-03-24  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 2024-03-25  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 2024-03-26  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 2024-03-27  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.33
# 2024-03-28  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.07
#
#             snow  snwd  tmax  tmin  target  rolling_3_tmax  \
# DATE
# 1970-01-01   0.0   0.0    30    23    34.0             NaN
# 1970-01-02   0.0   0.0    34    18    34.0             NaN
# 1970-01-03   0.4   0.0    34    24    28.0       32.666667
# 1970-01-04   0.0   0.0    28    19    35.0       32.000000
# 1970-01-05   0.0   0.0    35    16    36.0       32.333333
# ...          ...   ...   ...   ...     ...             ...
# 2024-03-24   0.0   0.0    49    29    55.0       49.000000
# 2024-03-25   0.0   0.0    55    34    60.0       52.000000
# 2024-03-26   0.0   0.0    60    38    50.0       54.666667
# 2024-03-27   0.0   0.0    50    43    51.0       55.000000
# 2024-03-28   0.0   0.0    51    45    51.0       53.666667
#
#             rolling_3_tmax_pct  rolling_3_tmin  rolling_3_tmin_pct  \
# DATE
# 1970-01-01                 NaN             NaN                 NaN
# 1970-01-02                 NaN             NaN                 NaN
# 1970-01-03            0.040816       21.666667            0.107692
# 1970-01-04           -0.125000       20.333333           -0.065574
# 1970-01-05            0.082474       19.666667           -0.186441
# ...                        ...             ...                 ...
# 2024-03-24            0.000000       30.000000           -0.033333
# 2024-03-25            0.057692       31.666667            0.073684
# 2024-03-26            0.097561       33.666667            0.128713
# 2024-03-27           -0.090909       38.333333            0.121739
# 2024-03-28           -0.049689       42.000000            0.071429
#
#             rolling_3_prcp  rolling_3_prcp_pct  rolling_14_tmax  \
# DATE
# 1970-01-01             NaN                 NaN              NaN
# 1970-01-02             NaN                 NaN              NaN
# 1970-01-03        0.013333               2.000              NaN
# 1970-01-04        0.013333              -1.000              NaN
# 1970-01-05        0.013333              -1.000              NaN
# ...                    ...                 ...              ...
# 2024-03-24        1.030000              -1.000        58.928571
# 2024-03-25        1.030000              -1.000        58.928571
# 2024-03-26        0.000000                 NaN        58.357143
# 2024-03-27        0.110000               2.000        56.714286
# 2024-03-28        0.133333              -0.475        54.857143
#
#             rolling_14_tmax_pct  rolling_14_tmin  rolling_14_tmin_pct  \
# DATE
# 1970-01-01                  NaN              NaN                  NaN
# 1970-01-02                  NaN              NaN                  NaN
# 1970-01-03                  NaN              NaN                  NaN
# 1970-01-04                  NaN              NaN                  NaN
# 1970-01-05                  NaN              NaN                  NaN
# ...                         ...              ...                  ...
# 2024-03-24            -0.168485        38.285714            -0.242537
# 2024-03-25            -0.066667        37.928571            -0.103578
# 2024-03-26             0.028152        37.714286             0.007576
# 2024-03-27            -0.118388        37.785714             0.137996
# 2024-03-28            -0.070312        37.785714             0.190926
#
#             rolling_14_prcp  rolling_14_prcp_pct
# DATE
# 1970-01-01              NaN                  NaN
# 1970-01-02              NaN                  NaN
# 1970-01-03              NaN                  NaN
# 1970-01-04              NaN                  NaN
# 1970-01-05              NaN                  NaN
# ...                     ...                  ...
# 2024-03-24         0.220714            -1.000000
# 2024-03-25         0.220714            -1.000000
# 2024-03-26         0.220714            -1.000000
# 2024-03-27         0.244286             0.350877
# 2024-03-28         0.249286            -0.719198
#
# [19811 rows x 20 columns]

# %%
weather = weather.iloc[14:,:]

# %%
weather
# Out:
#                 station                                       name  prcp  \
# DATE
# 1970-01-15  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 1970-01-16  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 1970-01-17  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.24
# 1970-01-18  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.03
# 1970-01-19  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# ...                 ...                                        ...   ...
# 2024-03-24  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 2024-03-25  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 2024-03-26  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 2024-03-27  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.33
# 2024-03-28  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.07
#
#             snow  snwd  tmax  tmin  target  rolling_3_tmax  \
# DATE
# 1970-01-15   0.0   2.0    28    12    34.0       27.666667
# 1970-01-16   0.0   2.0    34    14    43.0       29.000000
# 1970-01-17   0.0   1.0    43    26    41.0       35.000000
# 1970-01-18   0.0   0.0    41    24    24.0       39.333333
# 1970-01-19   0.0   0.0    24    15    22.0       36.000000
# ...          ...   ...   ...   ...     ...             ...
# 2024-03-24   0.0   0.0    49    29    55.0       49.000000
# 2024-03-25   0.0   0.0    55    34    60.0       52.000000
# 2024-03-26   0.0   0.0    60    38    50.0       54.666667
# 2024-03-27   0.0   0.0    50    43    51.0       55.000000
# 2024-03-28   0.0   0.0    51    45    51.0       53.666667
#
#             rolling_3_tmax_pct  rolling_3_tmin  rolling_3_tmin_pct  \
# DATE
# 1970-01-15            0.012048       14.000000           -0.142857
# 1970-01-16            0.172414       13.000000            0.076923
# 1970-01-17            0.228571       17.333333            0.500000
# 1970-01-18            0.042373       21.333333            0.125000
# 1970-01-19           -0.333333       21.666667           -0.307692
# ...                        ...             ...                 ...
# 2024-03-24            0.000000       30.000000           -0.033333
# 2024-03-25            0.057692       31.666667            0.073684
# 2024-03-26            0.097561       33.666667            0.128713
# 2024-03-27           -0.090909       38.333333            0.121739
# 2024-03-28           -0.049689       42.000000            0.071429
#
#             rolling_3_prcp  rolling_3_prcp_pct  rolling_14_tmax  \
# DATE
# 1970-01-15        0.000000                 NaN        28.000000
# 1970-01-16        0.000000                 NaN        28.000000
# 1970-01-17        0.080000            2.000000        28.642857
# 1970-01-18        0.090000           -0.666667        29.571429
# 1970-01-19        0.090000           -1.000000        28.785714
# ...                    ...                 ...              ...
# 2024-03-24        1.030000           -1.000000        58.928571
# 2024-03-25        1.030000           -1.000000        58.928571
# 2024-03-26        0.000000                 NaN        58.357143
# 2024-03-27        0.110000            2.000000        56.714286
# 2024-03-28        0.133333           -0.475000        54.857143
#
#             rolling_14_tmax_pct  rolling_14_tmin  rolling_14_tmin_pct  \
# DATE
# 1970-01-15             0.000000        14.928571            -0.196172
# 1970-01-16             0.214286        14.642857            -0.043902
# 1970-01-17             0.501247        14.785714             0.758454
# 1970-01-18             0.386473        15.142857             0.584906
# 1970-01-19            -0.166253        15.071429            -0.004739
# ...                         ...              ...                  ...
# 2024-03-24            -0.168485        38.285714            -0.242537
# 2024-03-25            -0.066667        37.928571            -0.103578
# 2024-03-26             0.028152        37.714286             0.007576
# 2024-03-27            -0.118388        37.785714             0.137996
# 2024-03-28            -0.070312        37.785714             0.190926
#
#             rolling_14_prcp  rolling_14_prcp_pct
# DATE
# 1970-01-15         0.026429            -1.000000
# 1970-01-16         0.026429            -1.000000
# 1970-01-17         0.040714             4.894737
# 1970-01-18         0.042857            -0.300000
# 1970-01-19         0.042857            -1.000000
# ...                     ...                  ...
# 2024-03-24         0.220714            -1.000000
# 2024-03-25         0.220714            -1.000000
# 2024-03-26         0.220714            -1.000000
# 2024-03-27         0.244286             0.350877
# 2024-03-28         0.249286            -0.719198
#
# [19797 rows x 20 columns]

# %%
weather = weather.fillna(0)

# %%
def expand_mean(df):
    return df.expanding(1).mean()

for col in ["tmax", "tmin", "prcp"]:
    weather[f"month_avg_{col}"] = weather[col].groupby(weather.index.month, group_keys=False).apply(expand_mean)
    weather[f"day_avg_{col}"] = weather[col].groupby(weather.index.day_of_year, group_keys=False).apply(expand_mean)

# %%
weather
# Out:
#                 station                                       name  prcp  \
# DATE
# 1970-01-15  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 1970-01-16  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 1970-01-17  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.24
# 1970-01-18  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.03
# 1970-01-19  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# ...                 ...                                        ...   ...
# 2024-03-24  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 2024-03-25  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 2024-03-26  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 2024-03-27  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.33
# 2024-03-28  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.07
#
#             snow  snwd  tmax  tmin  target  rolling_3_tmax  \
# DATE
# 1970-01-15   0.0   2.0    28    12    34.0       27.666667
# 1970-01-16   0.0   2.0    34    14    43.0       29.000000
# 1970-01-17   0.0   1.0    43    26    41.0       35.000000
# 1970-01-18   0.0   0.0    41    24    24.0       39.333333
# 1970-01-19   0.0   0.0    24    15    22.0       36.000000
# ...          ...   ...   ...   ...     ...             ...
# 2024-03-24   0.0   0.0    49    29    55.0       49.000000
# 2024-03-25   0.0   0.0    55    34    60.0       52.000000
# 2024-03-26   0.0   0.0    60    38    50.0       54.666667
# 2024-03-27   0.0   0.0    50    43    51.0       55.000000
# 2024-03-28   0.0   0.0    51    45    51.0       53.666667
#
#             rolling_3_tmax_pct  ...  rolling_14_tmin  rolling_14_tmin_pct  \
# DATE                            ...
# 1970-01-15            0.012048  ...        14.928571            -0.196172
# 1970-01-16            0.172414  ...        14.642857            -0.043902
# 1970-01-17            0.228571  ...        14.785714             0.758454
# 1970-01-18            0.042373  ...        15.142857             0.584906
# 1970-01-19           -0.333333  ...        15.071429            -0.004739
# ...                        ...  ...              ...                  ...
# 2024-03-24            0.000000  ...        38.285714            -0.242537
# 2024-03-25            0.057692  ...        37.928571            -0.103578
# 2024-03-26            0.097561  ...        37.714286             0.007576
# 2024-03-27           -0.090909  ...        37.785714             0.137996
# 2024-03-28           -0.049689  ...        37.785714             0.190926
#
#             rolling_14_prcp  rolling_14_prcp_pct  month_avg_tmax  \
# DATE
# 1970-01-15         0.026429            -1.000000       28.000000
# 1970-01-16         0.026429            -1.000000       31.000000
# 1970-01-17         0.040714             4.894737       35.000000
# 1970-01-18         0.042857            -0.300000       36.500000
# 1970-01-19         0.042857            -1.000000       34.000000
# ...                     ...                  ...             ...
# 2024-03-24         0.220714            -1.000000       52.735571
# 2024-03-25         0.220714            -1.000000       52.736904
# 2024-03-26         0.220714            -1.000000       52.741176
# 2024-03-27         0.244286             0.350877       52.739565
# 2024-03-28         0.249286            -0.719198       52.738543
#
#             day_avg_tmax  month_avg_tmin  day_avg_tmin  month_avg_prcp  \
# DATE
# 1970-01-15     28.000000       12.000000     12.000000        0.000000
# 1970-01-16     34.000000       13.000000     14.000000        0.000000
# 1970-01-17     43.000000       17.333333     26.000000        0.080000
# 1970-01-18     41.000000       19.000000     24.000000        0.067500
# 1970-01-19     24.000000       18.200000     15.000000        0.054000
# ...                  ...             ...           ...             ...
# 2024-03-24     54.581818       34.722615     35.327273        0.122008
# 2024-03-25     56.072727       34.722190     37.036364        0.121936
# 2024-03-26     57.600000       34.724118     37.400000        0.121865
# 2024-03-27     57.545455       34.728983     38.654545        0.121987
# 2024-03-28     59.581818       34.735018     41.072727        0.121957
#
#             day_avg_prcp
# DATE
# 1970-01-15      0.000000
# 1970-01-16      0.000000
# 1970-01-17      0.240000
# 1970-01-18      0.030000
# 1970-01-19      0.000000
# ...                  ...
# 2024-03-24      0.042727
# 2024-03-25      0.112000
# 2024-03-26      0.097818
# 2024-03-27      0.116182
# 2024-03-28      0.196182
#
# [19797 rows x 26 columns]

# %%
predictors = weather.columns[~weather.columns.isin(["target", "name", "station"])]

# %%
predictors
# Out:
# Index(['prcp', 'snow', 'snwd', 'tmax', 'tmin', 'rolling_3_tmax',
#        'rolling_3_tmax_pct', 'rolling_3_tmin', 'rolling_3_tmin_pct',
#        'rolling_3_prcp', 'rolling_3_prcp_pct', 'rolling_14_tmax',
#        'rolling_14_tmax_pct', 'rolling_14_tmin', 'rolling_14_tmin_pct',
#        'rolling_14_prcp', 'rolling_14_prcp_pct', 'month_avg_tmax',
#        'day_avg_tmax', 'month_avg_tmin', 'day_avg_tmin', 'month_avg_prcp',
#        'day_avg_prcp'],
#       dtype='object')

# %%
predictions = backtest(weather, rr, predictors)

# %%
mean_absolute_error(predictions["actual"], predictions["prediction"])
# Out:
# 5.289706450446789

# %%
predictions.sort_values("diff", ascending=False)
# Out:
#             actual  prediction       diff
# DATE
# 2014-01-06    13.0   49.030327  36.030327
# 2022-12-23    18.0   47.450017  29.450017
# 2001-04-08    83.0   55.677011  27.322989
# 2006-03-12    79.0   52.414911  26.585089
# 1987-05-18    57.0   83.470914  26.470914
# ...            ...         ...        ...
# 1994-03-02    40.0   39.997968   0.002032
# 1998-10-29    62.0   61.998134   0.001866
# 2000-09-07    76.0   76.001655   0.001655
# 2014-11-28    45.0   44.999591   0.000409
# 2021-08-20    83.0   82.999874   0.000126
#
# [16147 rows x 3 columns]

# %%
weather.loc["1990-03-07":"1990-03-17"]
# Out:
#                 station                                       name  prcp  \
# DATE
# 1990-03-07  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 1990-03-08  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 1990-03-09  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.09
# 1990-03-10  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 1990-03-11  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.01
# 1990-03-12  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 1990-03-13  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 1990-03-14  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 1990-03-15  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 1990-03-16  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.00
# 1990-03-17  USW00013739  PHILADELPHIA INTERNATIONAL AIRPORT, PA US  0.85
#
#             snow  snwd  tmax  tmin  target  rolling_3_tmax  \
# DATE
# 1990-03-07   0.0   0.0    37    18    48.0       41.666667
# 1990-03-08   0.0   0.0    48    18    51.0       41.333333
# 1990-03-09   0.0   0.0    51    29    58.0       45.333333
# 1990-03-10   0.0   0.0    58    38    63.0       52.333333
# 1990-03-11   0.0   0.0    63    41    83.0       57.333333
# 1990-03-12   0.0   0.0    83    48    84.0       68.000000
# 1990-03-13   0.0   0.0    84    49    85.0       76.666667
# 1990-03-14   0.0   0.0    85    49    81.0       84.000000
# 1990-03-15   0.0   0.0    81    46    80.0       83.333333
# 1990-03-16   0.0   0.0    80    58    76.0       82.000000
# 1990-03-17   0.0   0.0    76    51    60.0       79.000000
#
#             rolling_3_tmax_pct  ...  rolling_14_tmin  rolling_14_tmin_pct  \
# DATE                            ...
# 1990-03-07           -0.112000  ...        26.428571            -0.318919
# 1990-03-08            0.161290  ...        25.428571            -0.292135
# 1990-03-09            0.125000  ...        24.142857             0.201183
# 1990-03-10            0.108280  ...        24.500000             0.551020
# 1990-03-11            0.098837  ...        26.285714             0.559783
# 1990-03-12            0.220588  ...        29.000000             0.655172
# 1990-03-13            0.095652  ...        31.071429             0.577011
# 1990-03-14            0.011905  ...        32.500000             0.507692
# 1990-03-15           -0.028000  ...        34.285714             0.341667
# 1990-03-16           -0.024390  ...        36.285714             0.598425
# 1990-03-17           -0.037975  ...        37.214286             0.370441
#
#             rolling_14_prcp  rolling_14_prcp_pct  month_avg_tmax  \
# DATE
# 1990-03-07         0.034286            -1.000000       51.786284
# 1990-03-08         0.016429            -1.000000       51.780255
# 1990-03-09         0.015000             5.000000       51.779014
# 1990-03-10         0.010714            -1.000000       51.788889
# 1990-03-11         0.011429            -0.125000       51.806656
# 1990-03-12         0.011429            -1.000000       51.856013
# 1990-03-13         0.007857            -1.000000       51.906793
# 1990-03-14         0.007857            -1.000000       51.958991
# 1990-03-15         0.007857            -1.000000       52.004724
# 1990-03-16         0.007857            -1.000000       52.048742
# 1990-03-17         0.068571            11.395833       52.086342
#
#             day_avg_tmax  month_avg_tmin  day_avg_tmin  month_avg_prcp  \
# DATE
# 1990-03-07     47.714286       33.429027     29.904762        0.113094
# 1990-03-08     48.095238       33.404459     29.952381        0.112914
# 1990-03-09     49.714286       33.397456     30.714286        0.112878
# 1990-03-10     48.619048       33.404762     30.714286        0.112698
# 1990-03-11     49.904762       33.416799     30.904762        0.112536
# 1990-03-12     51.095238       33.439873     33.190476        0.112358
# 1990-03-13     52.142857       33.464455     33.857143        0.112180
# 1990-03-14     53.761905       33.488959     35.714286        0.112003
# 1990-03-15     52.857143       33.508661     35.333333        0.111827
# 1990-03-16     52.761905       33.547170     34.380952        0.111651
# 1990-03-17     53.238095       33.574568     33.380952        0.112810
#
#             day_avg_prcp
# DATE
# 1990-03-07      0.081429
# 1990-03-08      0.066667
# 1990-03-09      0.047143
# 1990-03-10      0.074762
# 1990-03-11      0.070952
# 1990-03-12      0.071429
# 1990-03-13      0.089524
# 1990-03-14      0.260000
# 1990-03-15      0.039524
# 1990-03-16      0.111905
# 1990-03-17      0.079048
#
# [11 rows x 26 columns]

# %%
predictions["diff"].round().value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='diff'>
